# %%
import pandas as pd

# %%
df = pd.read_csv("gpu_compute_database - Database.csv")

# %%
print(df.head())
# Out:
#                        Service         Provider     Category  \
# 0  Hugging Face Spaces ZeroGPU     Hugging Face  ML platform
# 1             Kaggle Notebooks  Kaggle / Google     Notebook
# 2  Amazon SageMaker Studio Lab              AWS     Notebook
# 3          Lightning AI Studio     Lightning AI  ML platform
# 4                 Google Colab           Google     Notebook
#
#                         GPU / Compute                                 VRAM  \
# 0  NVIDIA H200 via dynamic allocation  141 GB HBM3 per H200 (shared infra)
# 1                         P100/T4/TPU                                16 GB
# 2                            T4 + CPU                                16 GB
# 3                          T4/L4/A10G                             16-24 GB
# 4                     T4/K80/A100/TPU                             16-40 GB
#
#   Free Tier Type                       Max GPU Hours / Credits  \
# 0      Free tier                     Daily quota / queue based
# ...
